# %% [markdown]
# ## IMDB Top 1000 Analysis

# %%
# import packages
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure

# %%
# import data
df = pd.read_csv(r"C:\Users\Alexander\Documents\data_science_projects\movies_data\imdb_top_1000.csv")

# %%
# view the data
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
# check for missing data

for i in df.columns:
    missing = np.sum(df[i].isnull())
    print(f'{i}: {missing}')
# Out:
# Poster_Link: 0
# Series_Title: 0
# Released_Year: 0
# Certificate: 101
# Runtime: 0
# Genre: 0
# IMDB_Rating: 0
# Overview: 0
# Meta_score: 157
# Director: 0
# Star1: 0
# Star2: 0
# Star3: 0
# Star4: 0
# No_of_Votes: 0
# Gross: 169

# %% [markdown]
# Certificate is not important for our analysis, that is okay if it is missing data. We will drop rows that have a missing Meta Score and then a Gross value.

# %%
# drop the values
df = df.dropna(subset = ['Meta_score', 'Gross'])

# check number of missing
for i in df.columns:
    missing = np.sum(df[i].isnull())
    print(f'{i}: {missing}')
# Out:
# Poster_Link: 0
# Series_Title: 0
# Released_Year: 0
# Certificate: 36
# Runtime: 0
# Genre: 0
# IMDB_Rating: 0
# Overview: 0
# Meta_score: 0
# Director: 0
# Star1: 0
# Star2: 0
# Star3: 0
# Star4: 0
# No_of_Votes: 0
# Gross: 0

# %%
# check the data types
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %% [markdown]
# We will need to change a few columns. Released_Year, RunTime, and Gross will need to be converted to numerical columns.
#
# We will note, Released Year has PG as an entered value. We will remove that first

# %%
# filter out movie with PG
df = df[df['Released_Year'] != 'PG']

# change released year
df['Released_Year'] = df['Released_Year'].astype('int64')

df['Released_Year'].unique()
# Out:
# array([1994, 1972, 2008, 1974, 1957, 2003, 1993, 2010, 1999, 2001, 1966,
#        2002, 1990, 1980, 1975, 2019, 2014, 1998, 1997, 1995, 1991, 1977,
#        1954, 2011, 2006, 2000, 1988, 1985, 1968, 1960, 1942, 1936, 1931,
#        2018, 2016, 2017, 2012, 2009, 1981, 1979, 1964, 2004, 1992, 1987,
#        1986, 1984, 1983, 1976, 1973, 1971, 1965, 1962, 1959, 1958, 1952,
#        1944, 1941, 1927, 2013, 2007, 2005, 1989, 1963, 1955, 1950, 1948,
#        2015, 1996, 1982, 1978, 1967, 1951, 1949, 1940, 1939, 1934, 1970,
#        1969, 1961, 1946, 1930, 1925, 1947, 1938, 1933, 1935, 1953],
#       dtype=int64)

# %%
# we will note gross has , listed in the values
# we need to remove then convert to numerical

# replace commas
df['Gross'] = df["Gross"].str.replace(',', '')

# change gross
df['Gross'] = df['Gross'].astype('int64')

df['Gross'].unique()
# Out:
# array([ 28341469, 134966411, 534858444,  57300000,   4360000, 377845905,
#        107928762,  96898818, 292576195,  37030102, 315544750, 330252182,
#          6100000, 342551365, 171479930,  46836394, 290475067, 112000000,
#         48169908,  75505856,  10725228, 141340178,  82418501,   6153939,
#          5080409, 156452370,   1544889,  43984230,  22238696,   7153487,
#          8551228,  10631333,  10600000,  54000000,  78912963,  47212904,
#         54800000,  83400000,  47000000,   1924733, 119500000,  29800000,
#          7056013,  15630710,  35900000,  44527234,  45300000,  28350000,
#         51081062,  11403529,   4905000,     52709,    536118,  76408097,
#         26020957, 142502728,    566356,   5904366,  24801212,  13122642,
#           845464, 389813101, 107825862,  18340051,  72313754, 608581744,
#        248757044,  46889293, 109767581,   1092800,  26862450,  37707719,
#        208545589,   4105123,  41003371,  19202743, 215288866, 171243005,
#          1008098, 251513985,  35014192,  48071303,  75605492,   3185812,
#         75590286, 209028679, 255959475,   9422422,  69951824,  17114882,
#         38634938,    686383,  88513495,  20300218,  10301706,  24633730,
#         39868642,      6013, 301959197, 210614939,  23089926, 107509799,
#         24149632,  56000369,   3081925,    697181,    548707,   6167817,
#          5739376,  16290476,     45289,  51680613,  13060843,  57938693,
#         45064915,  52364010,  13622333, 317575550,  96522687,  52990775,
#         51401758, 132072926,  50668906,  15070285,   7267585,  36400491,
#        120620254,  10680275,  14378331,  49100000,   3796699,  43182776,
#        100012499,   1037847,  71516617,   1464625,  40903593,   7993039,
#         52929168,    453243,   1794187, 285761243,  66666062,  92823600,
#        111543479,  78756177,  49530280,  65207127,   2150000, 119285432,
#         12465371,  22490039,  76657000,  43000000,  35000000, 132088635,
#           959000,    696690,   1378435, 141843612,  13780024,  30500000],
#       dtype=int64)

# %%
# let's extract the run time value and away from the min unit

# split the old column into two new columns
df[['length', 'unit']] = df['Runtime'].str.split(' ', expand=True)
df['length'] = df['length'].astype('int64')

df['length'].unique()
# Out:
# array([142, 175, 152, 202,  96, 201, 154, 195, 148, 139, 178, 161, 179,
#        136, 146, 124, 133, 132, 169, 130, 125, 189, 116, 127, 118, 121,
#        207, 122, 106, 112, 151, 150, 155, 119, 110,  88, 137, 165, 109,
#        102,  87, 126, 117, 181, 149, 105, 164, 170,  98, 101, 113, 134,
#        115, 147,  95, 123, 131, 153, 108, 104,  89,  81,  99, 160, 114,
#        129, 228, 128, 103, 107, 140, 138, 180, 158, 156, 135,  86, 162,
#         91, 172, 145, 196,  93, 120,  80, 111, 100, 141,  92, 224, 188,
#         94, 183, 212, 238, 144, 143, 186,  83,  76,  90,  84, 191, 197,
#        174,  75, 157, 209,  97,  82,  85, 168, 166, 192, 194, 159, 193,
#         72, 163,  71,  78], dtype=int64)

# %% [markdown]
# We have cleaned up our data a bit. Let's take a look at our dataset by best rated movies

# %%
# sort by IMDB rating descending
df.sort_values(['IMDB_Rating'], ascending=False)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 915  https://m.media-amazon.com/images/M/MV5BMjEzOT...
# 914  https://m.media-amazon.com/images/M/MV5BMTg0Nj...
# 912  https://m.media-amazon.com/images/M/MV5BMTU5MD...
# 911  https://m.media-amazon.com/images/M/MV5BYmFmNj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A  142 min
# 1               The Godfather           1972           A  175 min
# 2             The Dark Knight           2008          UA  152 min
# 3      The Godfather: Part II           1974           A  202 min
# 4                12 Angry Men           1957           U   96 min
# ..                        ...            ...         ...      ...
# 915            The Blind Side           2009          UA  129 min
# 914           Sherlock Holmes           2009       PG-13  128 min
# 912                Zombieland           2009           A   88 min
# 911        La piel que habito           2011           R  120 min
# 997     From Here to Eternity           1953      Passed  118 min
#
#                           Genre  IMDB_Rating  \
# 0                         Drama          9.3
# 1                  Crime, Drama          9.2
# 2          Action, Crime, Drama          9.0
# 3                  Crime, Drama          9.0
# 4                  Crime, Drama          9.0
# ..                          ...          ...
# 915     Biography, Drama, Sport          7.6
# 914  Action, Adventure, Mystery          7.6
# 912  Adventure, Comedy, Fantasy          7.6
# 911     Drama, Horror, Thriller          7.6
# 997         Drama, Romance, War          7.6
#
#                                               Overview  Meta_score  \
# 0    Two imprisoned men bond over a number of years...        80.0
# 1    An organized crime dynasty's aging patriarch t...       100.0
# 2    When the menace known as the Joker wreaks havo...        84.0
# 3    The early life and career of Vito Corleone in ...        90.0
# 4    A jury holdout attempts to prevent a miscarria...        96.0
# ..                                                 ...         ...
# 915  The story of Michael Oher, a homeless and trau...        53.0
# 914  Detective Sherlock Holmes and his stalwart par...        57.0
# 912  A shy student trying to reach his family in Oh...        73.0
# 911  A brilliant plastic surgeon, haunted by past t...        70.0
# 997  In Hawaii in 1941, a private is cruelly punish...        85.0
#
#                  Director              Star1             Star2  \
# 0          Frank Darabont        Tim Robbins    Morgan Freeman
# 1    Francis Ford Coppola      Marlon Brando         Al Pacino
# 2       Christopher Nolan     Christian Bale      Heath Ledger
# 3    Francis Ford Coppola          Al Pacino    Robert De Niro
# 4            Sidney Lumet        Henry Fonda       Lee J. Cobb
# ..                    ...                ...               ...
# 915      John Lee Hancock      Quinton Aaron    Sandra Bullock
# 914           Guy Ritchie  Robert Downey Jr.          Jude Law
# 912       Ruben Fleischer    Jesse Eisenberg        Emma Stone
# 911       Pedro Almodóvar   Antonio Banderas       Elena Anaya
# 997        Fred Zinnemann     Burt Lancaster  Montgomery Clift
#
#                Star3            Star4  No_of_Votes      Gross  length unit
# 0         Bob Gunton   William Sadler      2343110   28341469     142  min
# 1         James Caan     Diane Keaton      1620367  134966411     175  min
# 2      Aaron Eckhart    Michael Caine      2303232  534858444     152  min
# 3      Robert Duvall     Diane Keaton      1129952   57300000     202  min
# 4      Martin Balsam     John Fiedler       689845    4360000      96  min
# ..               ...              ...          ...        ...     ...  ...
# 915       Tim McGraw         Jae Head       293266  255959475     129  min
# 914   Rachel McAdams      Mark Strong       583158  209028679     128  min
# 912  Woody Harrelson  Abigail Breslin       520041   75590286      88  min
# 911       Jan Cornet   Marisa Paredes       138959    3185812     120  min
# 997     Deborah Kerr       Donna Reed        43374   30500000     118  min
#
# [749 rows x 18 columns]

# %% [markdown]
# #### Running the correlation

# %% [markdown]
# What are the most correlated variables to higher IMDB rating?

# %%
# first let's create a scatter plot of revenue and rating

plt.scatter(data = df, x='Gross', y='IMDB_Rating')
plt.title("Gross Movie Revenue vs. IMDB Rating")
plt.xlabel("Gross Revenue")
plt.ylabel("IMDB Rating")

plt.show()

# %% [markdown]
# It already seems that higher revenue grossing films are not necessarily higher rated.

# %%
# let's find the actual correlation line

sns.regplot(data=df, x='Gross', y='IMDB_Rating',
            scatter_kws = {'color': "green"}, line_kws = {"color":"orange"})
plt.show()

# %% [markdown]
# The regplot line does seem to have a slight upwards trend. What is the scale of this relationship, such as the correlation?

# %%
# compute correlation for appropriate columns
df[['Gross', 'Released_Year', 'IMDB_Rating', 'Meta_score', 'No_of_Votes', 'length']].corr().round(2)
# Out:
#                Gross  Released_Year  IMDB_Rating  Meta_score  No_of_Votes  \
# Gross           1.00           0.24         0.13       -0.03         0.56
# Released_Year   0.24           1.00        -0.18       -0.31         0.20
# IMDB_Rating     0.13          -0.18         1.00        0.28         0.61
# Meta_score     -0.03          -0.31         0.28        1.00         0.01
# No_of_Votes     0.56           0.20         0.61        0.01         1.00
# length          0.17           0.01         0.26       -0.01         0.22
#
#                length
# Gross            0.17
# Released_Year    0.01
# IMDB_Rating      0.26
# Meta_score      -0.01
# No_of_Votes      0.22
# length           1.00

# %%
# let's create a visual to distinguish high correlation and low correlation

correlation_matrix = df[['Gross', 'Released_Year', 'IMDB_Rating', 'Meta_score', 'No_of_Votes', 'length']].corr().round(2)

# graph out
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix for Numerical Variables")
plt.xlabel("Numeric Movie Variables")
plt.show()

# %%
# let's look at converting the object variables to numeric

df2 = df.drop(columns=['unit', 'Poster_Link'])

# convert categorical to numeric code
for i in df2.columns:
    if(df2[i].dtype == "object"):
        df2[i] = df2[i].astype('category')
        df2[i] = df2[i].cat.codes # convert each into a value

df2
# Out:
#      Series_Title  Released_Year  Certificate  Runtime  Genre  IMDB_Rating  \
# 0             660           1994            0       42    118          9.3
# 1             589           1972            0       72    106          9.2
# 2             573           2008           11       52     18          9.0
# 3             590           1974            0       89    106          9.0
# 4               1           1957            9      117    106          9.0
# ..            ...            ...          ...      ...    ...          ...
# 990           229           1971            4       57    159          7.6
# 991           311           1970            3       44     39          7.6
# 992           613           1967            9      100     60          7.6
# 994            19           1964            9      108    100          7.6
# 997           219           1953            6       18    151          7.6
#
#      Overview  Meta_score  Director  Star1  Star2  Star3  Star4  No_of_Votes  \
# 0         687        80.0       110    459    432     61    690      2343110
# 1         347       100.0       106    324      4    250    155      1620367
# 2         728        84.0        61     97    208      0    473      2303232
# 3         605        90.0       106      6    491    521    155      1129952
# 4          99        96.0       358    196    349    404    315       689845
# ..        ...         ...       ...    ...    ...    ...    ...          ...
# 990       109        77.0       354    404    241    536    437        30144
# 991        83        50.0        44    103    568    153    105        45338
# 992       369        65.0       415    378    531    389     88       166409
# 994       551        96.0       320    256    465    201    567        40351
# 997       457        85.0       113     72    430    142    165        43374
#
#          Gross  length
# 0     28341469     142
# 1    134966411     175
# 2    534858444     152
# 3     57300000     202
# 4      4360000      96
# ..         ...     ...
# 990     696690     157
# 991    1378435     144
# 992  141843612      78
# 994   13780024      87
# 997   30500000     118
#
# [749 rows x 16 columns]

# %% [markdown]
# See how we have converted everything into a numeric value now. Numerical representation of the categories.

# %%
# now we re-run the correlation matrix

correlation_matrix = df2.corr().round(2)

# graph out
plt.figure(figsize=(10,6)) # need to make the grid slightly larger so we can see the values
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix for Numerical Variables")
plt.xlabel("Numeric Movie Variables")
plt.show()

# %% [markdown]
# To be honest, that did not provide much information. Likely because each of those categories are too small to establish a true relationship. We need much more data from other movies as well.

# %%
# create a small stack of the correlations
correlation_matrix_unstack = df2.corr()
corr_pairs = correlation_matrix_unstack.unstack()
print(corr_pairs.sort_values().to_string())
# Out:
# Gross          Genre           -0.341156
# Genre          Gross           -0.341156
# Meta_score     Released_Year   -0.306421
# Released_Year  Meta_score      -0.306421
# Genre          No_of_Votes     -0.200167
# No_of_Votes    Genre           -0.200167
# Certificate    Genre           -0.183487
# Genre          Certificate     -0.183487
# Released_Year  IMDB_Rating     -0.179065
# IMDB_Rating    Released_Year   -0.179065
# Genre          Released_Year   -0.143461
# Released_Year  Genre           -0.143461
# Certificate    Meta_score      -0.098029
# Meta_score     Certificate     -0.098029
# Overview       Genre           -0.095780
# Genre          Overview        -0.095780
# Runtime        Released_Year   -0.088507
# Released_Year  Runtime         -0.088507
# Director       Gross           -0.062680
# Gross          Director        -0.062680
# Director       Meta_score      -0.060837
# Meta_score     Director        -0.060837
# Certificate    IMDB_Rating     -0.059277
# IMDB_Rating    Certificate     -0.059277
# Genre          Series_Title    -0.056806
# Series_Title   Genre           -0.056806
# Star4          Director        -0.046627
# Director       Star4           -0.046627
# Overview       Star3           -0.045667
# Star3          Overview        -0.045667
# No_of_Votes    Director        -0.039520
# Director       No_of_Votes     -0.039520
# No_of_Votes    Star2           -0.039185
# Star2          No_of_Votes     -0.039185
# Star1          Genre           -0.036237
# Genre          Star1           -0.036237
# Star1          Meta_score      -0.036066
# Meta_score     Star1           -0.036066
# length         Genre           -0.035688
# Genre          length          -0.035688
# Director       Genre           -0.033010
# Genre          Director        -0.033010
# Star3          Star1           -0.032922
# Star1          Star3           -0.032922
# Gross          Meta_score      -0.030560
# Meta_score     Gross           -0.030560
# Star3          No_of_Votes     -0.029315
# No_of_Votes    Star3           -0.029315
# Series_Title   length          -0.029247
# length         Series_Title    -0.029247
# Director       IMDB_Rating     -0.028201
# IMDB_Rating    Director        -0.028201
# length         Director        -0.027887
# Director       length          -0.027887
# Star1          Star4           -0.025589
# Star4          Star1           -0.025589
# Runtime        Genre           -0.024152
# Genre          Runtime         -0.024152
# Star3          IMDB_Rating     -0.021585
# IMDB_Rating    Star3           -0.021585
# Certificate    Runtime         -0.019716
# Runtime        Certificate     -0.019716
# Star3          Runtime         -0.017351
# Runtime        Star3           -0.017351
# Star4          Meta_score      -0.017187
# Meta_score     Star4           -0.017187
# Series_Title   Director        -0.016407
# Director       Series_Title    -0.016407
# Star4          Gross           -0.015905
# Gross          Star4           -0.015905
# length         Certificate     -0.014389
# Certificate    length          -0.014389
# Meta_score     length          -0.012183
# length         Meta_score      -0.012183
# Star2          Meta_score      -0.011587
# Meta_score     Star2           -0.011587
# Star3          Series_Title    -0.010563
# Series_Title   Star3           -0.010563
# Certificate    Star2           -0.008551
# Star2          Certificate     -0.008551
# Director       Released_Year   -0.007550
# Released_Year  Director        -0.007550
# No_of_Votes    Star4           -0.006659
# Star4          No_of_Votes     -0.006659
# Series_Title   Released_Year   -0.006510
# Released_Year  Series_Title    -0.006510
# Gross          Star2           -0.005783
# Star2          Gross           -0.005783
# Star4          Released_Year   -0.004398
# Released_Year  Star4           -0.004398
# No_of_Votes    Runtime         -0.001721
# Runtime        No_of_Votes     -0.001721
# Star3          Gross           -0.001624
# Gross          Star3           -0.001624
# Meta_score     Overview        -0.001393
# Overview       Meta_score      -0.001393
# Star3          length          -0.001181
# length         Star3           -0.001181
# Star4          length          -0.001158
# length         Star4           -0.001158
# Star4          IMDB_Rating     -0.000550
# IMDB_Rating    Star4           -0.000550
# Star1          length          -0.000074
# length         Star1           -0.000074
# Star4          Series_Title     0.000261
# Series_Title   Star4            0.000261
# Star3          Certificate      0.000443
# Certificate    Star3            0.000443
# Runtime        Gross            0.001070
# Gross          Runtime          0.001070
# Series_Title   Meta_score       0.002035
# Meta_score     Series_Title     0.002035
# Star2          Genre            0.002564
# Genre          Star2            0.002564
# Star1          No_of_Votes      0.003769
# No_of_Votes    Star1            0.003769
# Released_Year  Star3            0.006578
# Star3          Released_Year    0.006578
# Star2          Star1            0.006984
# Star1          Star2            0.006984
# Star2          Released_Year    0.007556
# Released_Year  Star2            0.007556
# Overview       IMDB_Rating      0.008307
# IMDB_Rating    Overview         0.008307
# Meta_score     No_of_Votes      0.010298
# No_of_Votes    Meta_score       0.010298
# Overview       Star4            0.010660
# Star4          Overview         0.010660
# Star3          Star2            0.012970
# Star2          Star3            0.012970
# length         Released_Year    0.012976
# Released_Year  length           0.012976
# Gross          Star1            0.013094
# Star1          Gross            0.013094
# Series_Title   Star2            0.013825
# Star2          Series_Title     0.013825
# Overview       Certificate      0.014253
# Certificate    Overview         0.014253
# Series_Title   Certificate      0.015170
# Certificate    Series_Title     0.015170
# Overview       No_of_Votes      0.016660
# No_of_Votes    Overview         0.016660
# Star4          Star3            0.018437
# Star3          Star4            0.018437
# Overview       Star1            0.018597
# Star1          Overview         0.018597
# Genre          Star3            0.020640
# Star3          Genre            0.020640
# Released_Year  Star1            0.022154
# Star1          Released_Year    0.022154
# length         Runtime          0.023673
# Runtime        length           0.023673
# IMDB_Rating    Series_Title     0.023866
# Series_Title   IMDB_Rating      0.023866
# Overview       length           0.027124
# length         Overview         0.027124
# Star4          Certificate      0.028169
# Certificate    Star4            0.028169
# Star4          Star2            0.028179
# Star2          Star4            0.028179
# Star1          Runtime          0.028819
# Runtime        Star1            0.028819
# Director       Star2            0.029093
# Star2          Director         0.029093
# Director       Certificate      0.029299
# Certificate    Director         0.029299
# IMDB_Rating    Star2            0.031639
# Star2          IMDB_Rating      0.031639
# Star1          Certificate      0.033661
# Certificate    Star1            0.033661
# IMDB_Rating    Star1            0.034310
# Star1          IMDB_Rating      0.034310
# Series_Title   Star1            0.036185
# Star1          Series_Title     0.036185
# IMDB_Rating    Genre            0.036429
# Genre          IMDB_Rating      0.036429
# length         Star2            0.038163
# Star2          length           0.038163
# Runtime        Star4            0.039339
# Star4          Runtime          0.039339
# Runtime        Series_Title     0.040575
# Series_Title   Runtime          0.040575
# Star2          Runtime          0.042860
# Runtime        Star2            0.042860
# Director       Star3            0.043682
# Star3          Director         0.043682
# Meta_score     Star3            0.044119
# Star3          Meta_score       0.044119
# Series_Title   Gross            0.045271
# Gross          Series_Title     0.045271
#                Overview         0.047166
# Overview       Gross            0.047166
# Star1          Director         0.049294
# Director       Star1            0.049294
# Overview       Director         0.050327
# Director       Overview         0.050327
# Certificate    No_of_Votes      0.053154
# No_of_Votes    Certificate      0.053154
# Genre          Star4            0.059993
# Star4          Genre            0.059993
# Overview       Released_Year    0.061976
# Released_Year  Overview         0.061976
# Star2          Overview         0.066682
# Overview       Star2            0.066682
# No_of_Votes    Series_Title     0.068297
# Series_Title   No_of_Votes      0.068297
# IMDB_Rating    Runtime          0.068980
# Runtime        IMDB_Rating      0.068980
# Meta_score     Runtime          0.071074
# Runtime        Meta_score       0.071074
# Overview       Series_Title     0.071401
# Series_Title   Overview         0.071401
# Runtime        Overview         0.087566
# Overview       Runtime          0.087566
# Runtime        Director         0.111513
# Director       Runtime          0.111513
# Meta_score     Genre            0.122432
# Genre          Meta_score       0.122432
# IMDB_Rating    Gross            0.129378
# Gross          IMDB_Rating      0.129378
#                length           0.172226
# length         Gross            0.172226
# No_of_Votes    Released_Year    0.203316
# Released_Year  No_of_Votes      0.203316
# No_of_Votes    length           0.217457
# length         No_of_Votes      0.217457
# Certificate    Released_Year    0.221683
# Released_Year  Certificate      0.221683
# Gross          Released_Year    0.235951
# Released_Year  Gross            0.235951
# Gross          Certificate      0.249347
# Certificate    Gross            0.249347
# IMDB_Rating    length           0.257201
# length         IMDB_Rating      0.257201
# IMDB_Rating    Meta_score       0.282887
# Meta_score     IMDB_Rating      0.282887
# No_of_Votes    Gross            0.556003
# Gross          No_of_Votes      0.556003
# No_of_Votes    IMDB_Rating      0.614358
# IMDB_Rating    No_of_Votes      0.614358
# Series_Title   Series_Title     1.000000
# No_of_Votes    No_of_Votes      1.000000
# Star4          Star4            1.000000
# Star3          Star3            1.000000
# Star2          Star2            1.000000
# Star1          Star1            1.000000
# Director       Director         1.000000
# Meta_score     Meta_score       1.000000
# Overview       Overview         1.000000
# IMDB_Rating    IMDB_Rating      1.000000
# Genre          Genre            1.000000
# Runtime        Runtime          1.000000
# Certificate    Certificate      1.000000
# Released_Year  Released_Year    1.000000
# Gross          Gross            1.000000
# length         length           1.000000

# %% [markdown]
# We see the highest correlation with IMDB Scores is the No_of_Votes variable. Let's test the significance of this correlation.

# %%
from scipy.stats.stats import pearsonr
# Out:
# C:\Users\Alexander\AppData\Local\Temp\ipykernel_51344\4005289447.py:1: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import pearsonr

# %%
# produce the statistic
pearsonr(df2['IMDB_Rating'], df['No_of_Votes'])
# Out:
# PearsonRResult(statistic=0.6143575751494785, pvalue=6.363381993626154e-79)

# %% [markdown]
# We see the p-value is extremely low, indicating a significant correlation between IMDB rating and the no of votes.
